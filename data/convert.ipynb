# %%
import pandas as pd 
read_file = pd.read_excel ("train.xlsx") 
read_file.to_csv ("train.csv", 
				index = None, 
				header=True) 
df = pd.DataFrame(pd.read_csv("train.csv")) 
df
# Out:
#              date    airline ch_code  num_code dep_time       from time_taken  \
# 0      15-03-2022  Air India      AI       615    05:45     Mumbai    12h 45m
# 1      21-03-2022    Vistara      UK       930    07:30     Mumbai    15h 15m
# 2      10-03-2022    Vistara      UK       814    21:10  Bangalore    15h 25m
# 3      20-03-2022    Vistara      UK       836    10:45    Chennai    11h 05m
# 4      05-03-2022    Vistara      UK       706    10:15    Kolkata    11h 00m
# ...           ...        ...     ...       ...      ...        ...        ...
# 74784  24-02-2022    Vistara      UK       951    14:20      Delhi    08h 30m
# 74785  16-02-2022    Vistara      UK       774    20:35    Kolkata    20h 20m
# 74786  23-02-2022    Vistara      UK       876    21:35  Hyderabad    12h 05m
# 74787  20-02-2022  Air India      AI       865    10:40      Delhi    02h 10m
# 74788  21-02-2022    Vistara      UK       945    11:40      Delhi    11h 25m
#
# ...
